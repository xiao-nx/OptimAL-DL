# %%
import os
# restart colab
os.kill(os.getpid(), 9)

# %%
# check workpath
import os
print(os.getcwd())
 
# change workpath
from google.colab import drive
drive.mount('/content/gdrive')
path = "/content/gdrive/My Drive/IDS-WORK/OptimAL-DL/attention_bilstm"
os.chdir(path)
# check the files in workpatj
# !ls
# check CUDA version in Colab
# !nvcc --version

# %%
# !python main.py
