# %%
import os
# restart colab
os.kill(os.getpid(), 9)

# %%
# check workpath
import os
print(os.getcwd())
 
# change workpath
from google.colab import drive
drive.mount('/content/gdrive')
path = "/content/gdrive/My Drive/IDS-WORK/OptimAL-DL/src"
os.chdir(path)
# check the files in workpatj
# !ls
# Out:
# /content
# Mounted at /content/gdrive
# bilstm_attention.py  engine.py	  __pycache__	     textcnn.py
# config.py	     fasttext.py  run_bilstm.ipynb   train.py
# dataset.py	     lstm.py	  run_textcnn.ipynb

# %%
# check CUDA version in Colab
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0

# %%
# !python train.py
# Out:
# Loading embeddings start......
# tcmalloc: large alloc 2400002048 bytes == 0x55888ba20000 @  0x7f0e40ebeb6b 0x7f0e40ede379 0x7f0ded61725e 0x7f0ded6189d2 0x7f0e2b641e7d 0x7f0e3c23c120 0x7f0e3be7abd9 0x55886e9af8a8 0x55886ea22fd5 0x55886ea1d7ad 0x55886e9b03ea 0x55886ea1e3b5 0x55886ea1d7ad 0x55886e9b0003 0x55886e9afb09 0x55886eaf728d 0x55886ea661db 0x55886e9aebb1 0x55886ea9ffed 0x55886ea22988 0x55886ea1d7ad 0x55886e8efe2c 0x55886ea1fbb5 0x55886ea1d4ae 0x55886e9b03ea 0x55886ea227f0 0x55886ea1d4ae 0x55886e9b03ea 0x55886ea1f32a 0x55886ea1d4ae 0x55886e9b0c9f
# Loading embeddings end......
# vector size: torch.Size([11371, 300])
# To device...
# Training Model......
# Traceback (most recent call last):
#   File "train.py", line 208, in <module>
#     run()
#   File "train.py", line 173, in run
#     engine.train(train_it, model, optimizer, device)
#   File "/content/gdrive/My Drive/IDS-WORK/OptimAL-DL/src/engine.py", line 38, in train
#     predications = model(texts)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/content/gdrive/My Drive/IDS-WORK/OptimAL-DL/src/textcnn.py", line 43, in forward
#     out = torch.cat([self.conv_and_pool(out, conv) for conv in self.convs], 1)
#   File "/content/gdrive/My Drive/IDS-WORK/OptimAL-DL/src/textcnn.py", line 43, in <listcomp>
#     out = torch.cat([self.conv_and_pool(out, conv) for conv in self.convs], 1)
#   File "/content/gdrive/My Drive/IDS-WORK/OptimAL-DL/src/textcnn.py", line 36, in conv_and_pool
#     x = F.relu(conv(x)).squeeze(3)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py", line 399, in forward
#     return self._conv_forward(input, self.weight, self.bias)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py", line 396, in _conv_forward
#     self.padding, self.dilation, self.groups)
# RuntimeError: Expected 4-dimensional input for 4-dimensional weight [256, 1, 2, 300], but got 3-dimensional input of size [64, 1, 300] instead
