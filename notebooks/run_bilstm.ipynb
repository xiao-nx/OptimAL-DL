# %%
import os
# restart colab
os.kill(os.getpid(), 9)

# %%
# check workpath
import os
print(os.getcwd())
 
# change workpath
from google.colab import drive
drive.mount('/content/gdrive')
path = "/content/gdrive/My Drive/IDS-WORK/OptimAL-DL/src"
os.chdir(path)
# check the files in workpatj
# !ls
# Out:
# /content
# Mounted at /content/gdrive
# config.py   engine.py	 lstm.py      runmodel.ipynb
# dataset.py  fasttext.py  __pycache__  train.py

# %%
# check CUDA version in Colab
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0

# %%
# !python train.py
# Out:
# Loading embeddings start......
# tcmalloc: large alloc 2400002048 bytes == 0x55d888982000 @  0x7f56e299fb6b 0x7f56e29bf379 0x7f568f0f825e 0x7f568f0f99d2 0x7f56cd122e7d 0x7f56ddd1d120 0x7f56dd95bbd9 0x55d86bdc48a8 0x55d86be37fd5 0x55d86be327ad 0x55d86bdc53ea 0x55d86be333b5 0x55d86be327ad 0x55d86bdc5003 0x55d86bdc4b09 0x55d86bf0c28d 0x55d86be7b1db 0x55d86bdc3bb1 0x55d86beb4fed 0x55d86be37988 0x55d86be327ad 0x55d86bd04e2c 0x55d86be34bb5 0x55d86be324ae 0x55d86bdc53ea 0x55d86be377f0 0x55d86be324ae 0x55d86bdc53ea 0x55d86be3432a 0x55d86be324ae 0x55d86bdc5c9f
# Loading embeddings end......
# vector size: torch.Size([11371, 300])
# To device...
# cuda
# Training Model......
# Epoch: 0, Accuracy Score = 0.7224199288256228
# -----------------------------------------------------------
# | end of epoch   0 | time: 27.06s | valid accuracy    0.722
# -----------------------------------------------------------
# Epoch: 1, Accuracy Score = 0.7224199288256228
# -----------------------------------------------------------
# | end of epoch   1 | time: 27.29s | valid accuracy    0.722
# -----------------------------------------------------------
# Epoch: 2, Accuracy Score = 0.7188612099644128
# -----------------------------------------------------------
# | end of epoch   2 | time: 27.73s | valid accuracy    0.719
# -----------------------------------------------------------
# Epoch: 3, Accuracy Score = 0.7722419928825622
# -----------------------------------------------------------
# | end of epoch   3 | time: 28.18s | valid accuracy    0.772
# -----------------------------------------------------------
# Epoch: 4, Accuracy Score = 0.7473309608540926
# -----------------------------------------------------------
# | end of epoch   4 | time: 28.52s | valid accuracy    0.747
# -----------------------------------------------------------
# Epoch: 5, Accuracy Score = 0.7544483985765125
# -----------------------------------------------------------
# | end of epoch   5 | time: 28.85s | valid accuracy    0.754
# -----------------------------------------------------------
# Epoch: 6, Accuracy Score = 0.6797153024911032
# -----------------------------------------------------------
# | end of epoch   6 | time: 29.04s | valid accuracy    0.680
# -----------------------------------------------------------
# Epoch: 7, Accuracy Score = 0.701067615658363
# -----------------------------------------------------------
# | end of epoch   7 | time: 29.20s | valid accuracy    0.701
# -----------------------------------------------------------
# Epoch: 8, Accuracy Score = 0.7473309608540926
# -----------------------------------------------------------
# | end of epoch   8 | time: 29.59s | valid accuracy    0.747
# -----------------------------------------------------------
# Epoch: 9, Accuracy Score = 0.7330960854092526
# -----------------------------------------------------------
# | end of epoch   9 | time: 29.58s | valid accuracy    0.733
# -----------------------------------------------------------
