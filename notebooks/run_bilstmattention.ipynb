# %%
import os
# restart colab
os.kill(os.getpid(), 9)

# %%
# check workpath
import os
print(os.getcwd())
 
# change workpath
from google.colab import drive
drive.mount('/content/gdrive')
path = "/content/gdrive/My Drive/IDS-WORK/OptimAL-DL/src"
os.chdir(path)
# check the files in workpatj
# !ls
# Out:
# /content
# Mounted at /content/gdrive
# bilstm_attention.py  fasttext.py  run_bilstmattention.ipynb  train.py
# config.py	     lstm.py	  run_bilstm.ipynb
# dataset.py	     __pycache__  run_textcnn.ipynb
# engine.py	     rnn.py	  textcnn.py
# /content/gdrive/My Drive/IDS-WORK/OptimAL-DL/src
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# bilstm_attention.py  fasttext.py  run_bilstmattention.ipynb  train.py
# config.py	     lstm.py	  run_bilstm.ipynb
# dataset.py	     __pycache__  run_textcnn.ipynb
# engine.py	     rnn.py	  textcnn.py

# %%
# check CUDA version in Colab
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0

# %%
# !python train.py
# Out:
# Loading embeddings start......
# tcmalloc: large alloc 2400002048 bytes == 0x559674458000 @  0x7f56914b2b6b 0x7f56914d2379 0x7f563dc0b25e 0x7f563dc0c9d2 0x7f567bc35e7d 0x7f568c830120 0x7f568c46ebd9 0x55965753b8a8 0x5596575aefd5 0x5596575a97ad 0x55965753c3ea 0x5596575aa3b5 0x5596575a97ad 0x55965753c003 0x55965753bb09 0x55965768328d 0x5596575f21db 0x55965753abb1 0x55965762bfed 0x5596575ae988 0x5596575a97ad 0x55965747be2c 0x5596575abbb5 0x5596575a94ae 0x55965753c3ea 0x5596575ae7f0 0x5596575a94ae 0x55965753c3ea 0x5596575ab32a 0x5596575a94ae 0x55965753cc9f
# Loading embeddings end......
# vector size: torch.Size([11371, 300])
# To device...
# Training Model......
# Epoch: 0, Accuracy Score = 0.693950177935943
# -----------------------------------------------------------
# | end of epoch   0 | time: 1292.47s | valid accuracy    0.694
# -----------------------------------------------------------
# Epoch: 1, Accuracy Score = 0.6654804270462633
# -----------------------------------------------------------
# | end of epoch   1 | time: 1292.85s | valid accuracy    0.665
# -----------------------------------------------------------
# Epoch: 2, Accuracy Score = 0.7046263345195729
# -----------------------------------------------------------
# | end of epoch   2 | time: 1283.32s | valid accuracy    0.705
# -----------------------------------------------------------
# Epoch: 3, Accuracy Score = 0.701067615658363
# -----------------------------------------------------------
# | end of epoch   3 | time: 1286.32s | valid accuracy    0.701
# -----------------------------------------------------------
# Epoch: 4, Accuracy Score = 0.7153024911032029
# -----------------------------------------------------------
# | end of epoch   4 | time: 1283.66s | valid accuracy    0.715
# -----------------------------------------------------------
